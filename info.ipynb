# %%
import pandas as pd
import numpy as np
import missingno as msno
import re
import matplotlib.pyplot as plt

data = pd.read_csv('assets/Palworld_Data--Palu combat attribute table.csv')


# Afficher la dimensionnalité du DataFrame
print("Nombre de variable puis d'observation du DataFrame :", data.shape)
# Out:
# Nombre de variable puis d'observation du DataFrame : (149, 19)

# %%
# Vérifier les données manquantes
donnees_manquantes = data.isna().sum()

# Calculer la proportion en pourcentage
proportion_manquante = (donnees_manquantes / len(data)) * 100

# Afficher les données manquantes et la proportion en pourcentage
print("Données manquantes par colonne :")
print(donnees_manquantes)
print("\nProportion de données manquantes en pourcentage :")
print(proportion_manquante)
# Out:
# Données manquantes par colonne :
# PS: This table only refreshes the data and does not include all occurrences of Palu. For example, the level 10 Balrog Sheep and Mammoth fights that appear in Maple Leaf Forest are random events. pending upgrade     11
# Unnamed: 1                                                                                                                                                                                                             12
# Unnamed: 2                                                                                                                                                                                                             12
# Unnamed: 3                                                                                                                                                                                                             12
# Unnamed: 4                                                                                                                                                                                                            149
# Unnamed: 5                                                                                                                                                                                                              2
# Unnamed: 6                                                                                                                                                                                                              3
# Unnamed: 7                                                                                                                                                                                                              3
# Unnamed: 8                                                                                                                                                                                                              3
# Unnamed: 9                                                                                                                                                                                                              3
# Unnamed: 10                                                                                                                                                                                                           131
# Unnamed: 11                                                                                                                                                                                                             3
# Unnamed: 12                                                                                                                                                                                                           149
# Unnamed: 13                                                                                                                                                                                                             8
# Unnamed: 14                                                                                                                                                                                                             9
# Unnamed: 15                                                                                                                                                                                                             9
# Unnamed: 16                                                                                                                                                                                                             9
# Unnamed: 17                                                                                                                                                                                                           142
# Unnamed: 18                                                                                                                                                                                                             9
# dtype: int64
#
# Proportion de données manquantes en pourcentage :
# PS: This table only refreshes the data and does not include all occurrences of Palu. For example, the level 10 Balrog Sheep and Mammoth fights that appear in Maple Leaf Forest are random events. pending upgrade      7.382550
# Unnamed: 1                                                                                                                                                                                                              8.053691
# Unnamed: 2                                                                                                                                                                                                              8.053691
# Unnamed: 3                                                                                                                                                                                                              8.053691
# Unnamed: 4                                                                                                                                                                                                            100.000000
# Unnamed: 5                                                                                                                                                                                                              1.342282
# Unnamed: 6                                                                                                                                                                                                              2.013423
# Unnamed: 7                                                                                                                                                                                                              2.013423
# Unnamed: 8                                                                                                                                                                                                              2.013423
# Unnamed: 9                                                                                                                                                                                                              2.013423
# Unnamed: 10                                                                                                                                                                                                            87.919463
# Unnamed: 11                                                                                                                                                                                                             2.013423
# Unnamed: 12                                                                                                                                                                                                           100.000000
# Unnamed: 13                                                                                                                                                                                                             5.369128
# Unnamed: 14                                                                                                                                                                                                             6.040268
# Unnamed: 15                                                                                                                                                                                                             6.040268
# Unnamed: 16                                                                                                                                                                                                             6.040268
# Unnamed: 17                                                                                                                                                                                                            95.302013
# Unnamed: 18                                                                                                                                                                                                             6.040268
# dtype: float64

# %%
# Afficher un graphique représentatif des données manquantes
msno.matrix(data)
# Out:
# <Axes: >

# %%
data2 = pd.read_csv('assets/Palworld_Data--Palu refresh level.csv')

# Afficher la dimensionnalité du DataFrame
print("Nombre de variable puis d'observation du DataFrame :", data2.shape)

msno.matrix(data2)
# Out:
# Nombre de variable puis d'observation du DataFrame : (149, 19)
# <Axes: >
